# %% [markdown]
# ### Projet 2 - Analyse d’un phénomène environnemental inconnu.
#
# **À rendre avant le 19.12.2024 minuit.**
#
# ---
#
# #### **Synopsis**
#
# Vous travaillez comme data scientist pour une entreprise spécialisée dans la modélisation de systèmes physiques complexes. Une équipe d'experts a collecté des données sur un phénomène environnemental à l’aide d’un réseau de capteurs. Ces données, enregistrées toutes les 15 minutes entre le **1er janvier 2024** et le **29 février 2024**, contiennent des informations provenant de trois capteurs. Malheureusement, un capteur est devenu défectueux à partir du **20 février**, et votre objectif est d’approximer les valeurs manquantes.
#
# Le jeu de données non défecteuses sont disponibles dans le fichier _[./projet_2_data.csv](./projet_2_data.csv)_. Les colonnes sont :
#
# 1. **timestamp** : la date et l'heure de chaque observation (au format datetime).
# 2. **x1** : une première mesure physique observable liée au système.
# 3. **x2** : une seconde mesure physique observable liée au système.
# 4. **y** : la variable cible à reconstituer, représentant un comportement du système physique.
#
# Le jeu de données défecteuses sont disponibles dans le fichier _[./projet_2_hold_out.csv](./projet_2_hold_out.csv)_ qui n'inclus pas la variable cible.
#
# Les experts soupçonnent que la variable cible **y** dépend de plusieurs facteurs :
# - L’activité anthropique (jour de semaine ou week-end, heure de la journée, etc) selon un motif cyclique.
# - Les interactions temporelles des variables **x1** et **x2**, incluant un potentiel **décalage dans le temps (lag)** pouvant aller jusqu’à 30 minutes.
#
# Votre mission consiste à découvrir cette relation pour créer un modèle prédictif permettant de reconstituer les valeurs manquantes de **y**. Il vous revient de décider quel type de modèle est le plus adapté pour capturer cette relation.
#
# ---
#
# ### **Important**
#
# Ce problème est une simulation contenant des variables fictives. Il ne repose pas sur des connaissances physiques réelles. Ne vous appuyez pas sur une expertise métier pour résoudre ce problème : basez vos décisions sur les données et vos analyses, et des informations données ci-dessus.
#
# ---
#
# #### **Objectifs**
#
# 1. **Analyse exploratoire** :
#    - Visualiser les variations de **y** en fonction du temps, des variables explicatives, et des caractéristiques temporelles, etc.
#    - Identifier des motifs cycliques ou des relations structurelles dans les données.
#
# 2. **Transformation des données** :
#    - Extraire et créer des nouvelles caractéristiques pertinentes.
#    - Traiter les valeurs manquantes de manière appropriée.
#
# 3. **Construction du modèle** :
#    - Concevez un modèle capable de capturer efficacement les relations entre les variables explicatives et la variable cible.
#    - Vous pouvez tester plusieurs approches et choisir celle offrant les meilleures performances.
#
# 4. **Évaluation des performances** :
#    - Utiliser des métriques adaptées pour mesurer la qualité des prédictions.
#    - Vous pouvez comparer les performances entre plusieurs modèles ou configurations.
#
# 5. **Présentation des résultats** :
#    - Fournir un rapport clair et structuré expliquant vos choix méthodologiques, vos résultats, et vos conclusions.
#
# ---
#
# #### **Livrables**
#
# 1. **Modèle prédictif** :
#    - Un modèle entraîné sur les données avant le 20 février.
#
# 2. **Fonction de transformation** :
#    - Une fonction python permettant de préparer des données brutes à partir d'un fichier similaire à _[projet_2_hold_out.csv](./projet_2_hold_out.csv)_, qui peuvent être utilisées avec votre modèle prédictif. Cette fonction doit retourner une DataFrame pandas ou un array numpy utilisable par votre modèle (voir exemple _inputTransform_).
#
# 3. **Rapport** :
#    - Fournissez un _[rapport](./rapport.ipynb)_ bref et clair expliquant vos choix, vos résultats et les performances des modèles.
#    - Explication des étapes d’analyse exploratoire et de création des caractéristiques, avec une description claire des caractéristiques sélectionnées et de la méthodologie.
#    - Méthode de création du modèle, régularisations etc, avec justification de vos choix.
#    - Performance du modèle, et interpretation.
#
# ---
#
# #### **Astuces**
#
# 1. **Séries temporelles** :
#    - Assurez-vous de respecter l’ordre chronologique lors de la division des données en ensembles d’entraînement et de validation.
#
# 3. **Caractéristiques temporelles** :
#    - Transformez les informations temporelles en variables utiles (par exemple, type de jour, heure, etc.).
#    - Explorez l’influence des décalages temporels. Par exemple, la valeur de **x1** à un instant donné pourrait influencer **y** avec un retard de 15 ou 30 minutes.
#
# 4. **Nettoyage avant soumission** :
#    - Vérifiez que votre notebook s'exécute correctement de bout en bout en utilisant l’option _Restart Kernel and Run All Cells…_. Ensuite, nettoyez les sorties avec _Restart Kernel and Clear All Outputs…_.
#
# 5. **Fonctions utiles** :
#    - _pandas.DataFrame.shift_ : pour créer des décalages temporels sur vos colonnes.
#    - _pandas.concat_ : pour combiner plusieurs DataFrames ou colonnes.
#    - _pandas.get_dummies_ : pour créer des variables indicatrices (dummy variables) à partir de colonnes catégoriques.
#    - _pandas.read_csv_ : pour lire les données et traiter les timestamps correctement.
#    - _pandas.dropna_ : pour gérer les valeurs manquantes dans vos données.
#    - Fonctions de conversion des colonnes datetime : par exemple, _df.timestamp.dt.hour_, _df.timestamp.dt.minute_, et autres méthodes de l’objet pandas datetime pour extraire des informations temporelles pertinentes.
#    - _sklearn.model_selection.TimeSeriesSplit_ : pour diviser vos données temporelles en ensembles d'entraînement et de test tout en respectant l'ordre chronologique (sinon KFold, etc. changent l'ordre de manière aléatoire).
#
#
# ---
#
# #### **Évaluation**
#
# Cette question admet plusieurs solutions possibles. Une partie de la note sera attribuée en fonction de la cohérence et de la justification de vos choix. Votre rapport devra inclure une discussion expliquant la méthode utilisée, ainsi que l'interpretation des résultats obtenus.
#
# ---
#
# #### Barème - sur 6 points
#
# 1. **Qualité de la méthode et du code** :
#     - Noté sur 3 points, en tenant compte de la clarté, de l'organisation et de l'efficacité de l'approches utilisée.
#
# 2. **Vérification et analyse des résultats** :
#     - Noté sur 3 points, en fonction de la rigueur dans l'évaluation du modèle et de la pertinence des conclusions.
#
# 3. **Fonctionnalité** :
#     - Des points seront déduits si le notebook n'est pas fonctionnel, en fonction de la gravité des problèmes rencontrés et du nombre de corrections nécessaires pour le rendre opérationnel.
#
# Les notes incluent une évaluation des réponses fournies dans le rapport, en particulier la justification des choix effectués et l'interprétation des résultats et performances du modèle.

# %%
import pandas as pd
import sklearn as sk
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from mpl_toolkits.mplot3d import Axes3D
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import plotly.express as px

def tracer_fonction(x, y, nom_fonction, nom_abscisses):
    
    titre="Graphe de la fonction"
    couleur='blue'

    # Tracer le graphe
    plt.figure(figsize=(9, 7))
    plt.plot(x, y, color=couleur, label=f"f(x)")
    plt.title(titre, fontsize=14)
    plt.grid(True)
    plt.xlabel(nom_abscisses, fontsize=12)
    plt.ylabel(nom_fonction, fontsize=12)
    plt.show()

# Exemple de données (remplacez-les par vos propres données)
def tracer_3D(donnees):
    fig = px.scatter_3d(donnees, x='x1', y='x2', z='y', title="Graphique 3D interactif avec Plotly")
    fig.show()

def read_data():
    input_filename='./projet_2_data.csv'
    donnees = pd.read_csv(input_filename)

    # Conversion des données de date en heures par rapport au 1er janvier 2024 (utile pour la représentation)
    data_datetime = pd.to_datetime(donnees.iloc[:, 0])
    donnees.iloc[:,0] = data_datetime
    hours = data_datetime.dt.hour + data_datetime.dt.day*24 + data_datetime.dt.minute/60 + data_datetime.dt.month*24*31 - 768
    donnees.iloc[:, 0] = hours

    return donnees, data_datetime, hours


donnees, data_datetime, hours = read_data()

hold_out_filename='./projet_2_hold_out.csv'
donnees_a_predire = pd.read_csv(hold_out_filename)


#tracer_fonction(donnees.iloc[:, 0], donnees.iloc[:, 1], "X1", "timestamp")
#tracer_fonction(donnees.iloc[:, 0], donnees.iloc[:, 2], "X2", "timestamp")
tracer_fonction(donnees.iloc[:, 0], donnees.iloc[:, 3], "Y", "timestamp")

# Exploration et visualisation des données : 

# (0 = lundi, 1 = mardi, 2 = mercredi, 3= jeudi, 4 = vendredi, 5= samedi, 6 = dimanche)
day_of_week = (hours/24) % 7
day_of_month = (hours/24) % 31
hour_of_day = hours % 24
week_of_month = day_of_month / 7

print("Affichage selon jour de la semaine : ")
donnees.iloc[:,0] = day_of_week
tracer_fonction(donnees.iloc[:, 0], donnees.iloc[:, 3], "Y", "timestamp")

#print("Affichage selon jour du mois : ")
#donnees.iloc[:,0] = day_of_month
# tracer_fonction(donnees.iloc[:, 0], donnees.iloc[:, 1], "X1","timestamp")
# tracer_fonction(donnees.iloc[:, 0], donnees.iloc[:, 2], "X2","timestamp")
# tracer_fonction(donnees.iloc[:, 0], donnees.iloc[:, 3], "Y", "timestamp")


print("Affichage selon heure de la journée : ")
donnees.iloc[:,0] = hour_of_day
tracer_fonction(donnees.iloc[:, 0], donnees.iloc[:, 3], "Y", "timestamp")

# print("Affichage selon semaine du mois: ")
# donnees.iloc[:,0] = week_of_month
# tracer_fonction(donnees.iloc[:, 0], donnees.iloc[:, 3], "Y", "timestamp")

# print("Affichage données selon X1")
# tracer_fonction(donnees.iloc[:, 1], donnees.iloc[:, 3], "Y", "X1")
# print("Affichage données selon X2")
# tracer_fonction(donnees.iloc[:, 2], donnees.iloc[:, 3], "Y", "X2")
# Out:
# Affichage selon jour de la semaine :
# Affichage selon heure de la journée :

# %%
# Création d'un 1er modèle sans décalage temporel

# Création d'une table de données avec les caractéristiques importantes :
donnees_traitees = np.array([hour_of_day, day_of_week, donnees.iloc[:,1], donnees.iloc[:,2], donnees.iloc[:, 3]]).T

# Split des données entre données de test et données d'entrainement
X_entrainement = donnees_traitees[:3600, 0:4]
Y_entrainement = donnees_traitees[:3600, 4]
X_test = donnees_traitees[3600:, 0:4]
Y_test = donnees_traitees[3600:, 4]

# Créons un 1er modèle avec les données que nous avons noté :
polynomial_features= PolynomialFeatures(degree=5, include_bias=False)
X_train_transformed = polynomial_features.fit_transform(X_entrainement)
X_test_transformed = polynomial_features.transform(X_test)

model = LinearRegression()
model.fit(X_train_transformed, Y_entrainement)
Y_model = model.predict(X_test_transformed)
print("Mean absolute error (training data): ", mean_absolute_error(Y_test, Y_model))
print(f"Erreur quadratique moyenne (MSE) :",  mean_squared_error(Y_test, Y_model))
# Out:
# Mean absolute error (training data):  0.5310045050163518
# Erreur quadratique moyenne (MSE) : 0.4207488484744999

# %%
# Création d'un modèle brut sans traitement des données particulier

# Split des données entre données de test et données d'entrainement
X_entrainement = donnees.iloc[:3600, 0:3]
Y_entrainement = donnees.iloc[:3600, 3]
X_test = donnees.iloc[3600:, 0:3]
Y_test = donnees.iloc[3600:, 3]

# Créons un 1er modèle avec les données que nous avons noté :
polynomial_features= PolynomialFeatures(degree=1, include_bias=False)
X_train_transformed = polynomial_features.fit_transform(X_entrainement)
X_test_transformed = polynomial_features.transform(X_test)

model = LinearRegression()
model.fit(X_train_transformed, Y_entrainement)
Y_model = model.predict(X_test_transformed)
print("Mean absolute error (training data): ", mean_absolute_error(Y_test, Y_model))
print(f"Erreur quadratique moyenne (MSE) :",  mean_squared_error(Y_test, Y_model))

# ==> Résultats non concluents avec une erreur moyenne élevée
# Out:
# Mean absolute error (training data):  0.8286084813299106
# Erreur quadratique moyenne (MSE) : 1.0334671123025012

# %%
# Cherchons une corrélation avec un éventuel décalage temporel entre Y et X1 et X2 : 

temps = donnees.iloc[1100:1130, 0]
X1 = donnees.iloc[1100:1130, 1]
X2 = donnees.iloc[1100:1130, 2]
Y = donnees.iloc[1100:1130, 3]


titre="Graphe de la fonction"
# Tracer le graphe
plt.figure(figsize=(9, 7))
plt.plot(temps, X1, color='red', label=f"X1")
plt.plot(temps, X2, color='blue', label=f"X2")
plt.plot(temps, Y, color='green', label=f"Y")
plt.title(titre, fontsize=14)
plt.grid(True)
plt.xlabel('temps', fontsize=12)
plt.show()

# %%
# Nous allons désormais tester plusieurs modèles avec des décalages temporels différents :

# Cas 1 : Décalage de 15 min pour le capteur 1 et aucun décalage pour le capteur 2 : 
donnees,a, hours  = read_data()


datashifted = donnees['x1'].shift(1)
donnees.iloc[:, 1] = datashifted

X_entrainement = donnees.iloc[1:3600, 0:3]
Y_entrainement = donnees.iloc[1:3600, 3]
X_test = donnees.iloc[3600:, 0:3]
Y_test = donnees.iloc[3600:, 3]

polynomial_features= PolynomialFeatures(degree=1, include_bias=False)
X_train_transformed = polynomial_features.fit_transform(X_entrainement)
X_test_transformed = polynomial_features.transform(X_test)

model = LinearRegression()
model.fit(X_train_transformed, Y_entrainement)
Y_model = model.predict(X_test_transformed)
print("test 1 :")
print("Mean absolute error (training data): ", mean_absolute_error(Y_test, Y_model))
print(f"Erreur quadratique moyenne (MSE) :",  mean_squared_error(Y_test, Y_model))

# Ici pas vraiment d'amélioration notable avec un décalage de 15 min pour le capteur 1

# Prenons un decalage de 30 min pour le capteur 1 sans décalage pour le capteur 2
datashifted = donnees['x1'].shift(1)
donnees.iloc[:, 1] = datashifted

X_entrainement = donnees.iloc[2:3600, 0:3]
Y_entrainement = donnees.iloc[2:3600, 3]
X_test = donnees.iloc[3600:, 0:3]
Y_test = donnees.iloc[3600:, 3]

polynomial_features= PolynomialFeatures(degree=1, include_bias=False)
X_train_transformed = polynomial_features.fit_transform(X_entrainement)
X_test_transformed = polynomial_features.transform(X_test)

model = LinearRegression()
model.fit(X_train_transformed, Y_entrainement)
Y_model = model.predict(X_test_transformed)
print("test 2 :")
print("Mean absolute error (training data): ", mean_absolute_error(Y_test, Y_model))
print(f"Erreur quadratique moyenne (MSE) :",  mean_squared_error(Y_test, Y_model))

# Pas particulièrement d'amélioration notable

# Prenons désormais un shift de 15 min du capteur 2 sans shift du capteur 1.

donnees,a, hours  = read_data()

datashifted = donnees["x2"].shift(1)
donnees.iloc[:, 2] = datashifted

X_entrainement = donnees.iloc[1:3600, 0:3]
Y_entrainement = donnees.iloc[1:3600, 3]
X_test = donnees.iloc[3600:, 0:3]
Y_test = donnees.iloc[3600:, 3]

polynomial_features= PolynomialFeatures(degree=1, include_bias=False)
X_train_transformed = polynomial_features.fit_transform(X_entrainement)
X_test_transformed = polynomial_features.transform(X_test)

model = LinearRegression()
model.fit(X_train_transformed, Y_entrainement)
Y_model = model.predict(X_test_transformed)
print("test 3 :")
print("Mean absolute error (training data): ", mean_absolute_error(Y_test, Y_model))
print(f"Erreur quadratique moyenne (MSE) :",  mean_squared_error(Y_test, Y_model))

#Pas d'amélioration

# Test avec un décalage de 30 min du capteur 2 sans décalage du capteur 1 : 

datashifted = donnees['x2'].shift(1)
donnees.iloc[:, 1] = datashifted

X_entrainement = donnees.iloc[2:3600, 0:3]
Y_entrainement = donnees.iloc[2:3600, 3]
X_test = donnees.iloc[3600:, 0:3]
Y_test = donnees.iloc[3600:, 3]

polynomial_features= PolynomialFeatures(degree=1, include_bias=False)
X_train_transformed = polynomial_features.fit_transform(X_entrainement)
X_test_transformed = polynomial_features.transform(X_test)

model = LinearRegression()
model.fit(X_train_transformed, Y_entrainement)
Y_model = model.predict(X_test_transformed)
print("test 4 :")
print("Mean absolute error (training data): ", mean_absolute_error(Y_test, Y_model))
print(f"Erreur quadratique moyenne (MSE) :",  mean_squared_error(Y_test, Y_model))

# Pas d'amélioration notable 

# Test pour un décalage de 15 minutes des 2 capteurs : 

donnees,a, hours = read_data()

datashifted = donnees["x1"].shift(1)
donnees.iloc[:, 1] = datashifted
datashifted = donnees["x2"].shift(1)
donnees.iloc[:, 2] = datashifted

X_entrainement = donnees.iloc[1:3600, 0:3]
Y_entrainement = donnees.iloc[1:3600, 3]
X_test = donnees.iloc[3600:, 0:3]
Y_test = donnees.iloc[3600:, 3]

polynomial_features= PolynomialFeatures(degree=1, include_bias=False)
X_train_transformed = polynomial_features.fit_transform(X_entrainement)
X_test_transformed = polynomial_features.transform(X_test)

model = LinearRegression()
model.fit(X_train_transformed, Y_entrainement)
Y_model = model.predict(X_test_transformed)
print("test 5 :")
print("Mean absolute error (training data): ", mean_absolute_error(Y_test, Y_model))
print(f"Erreur quadratique moyenne (MSE) :",  mean_squared_error(Y_test, Y_model))

# Pas concluent 

# Test pour un décalage des 2 capteurs de 30 minutes : 

datashifted = donnees["x1"].shift(1)
donnees.iloc[:, 1] = datashifted
datashifted = donnees["x2"].shift(1)
donnees.iloc[:, 2] = datashifted

X_entrainement = donnees.iloc[2:3600, 0:3]
Y_entrainement = donnees.iloc[2:3600, 3]
X_test = donnees.iloc[3600:, 0:3]
Y_test = donnees.iloc[3600:, 3]

polynomial_features= PolynomialFeatures(degree=1, include_bias=False)
X_train_transformed = polynomial_features.fit_transform(X_entrainement)
X_test_transformed = polynomial_features.transform(X_test)

model = LinearRegression()
model.fit(X_train_transformed, Y_entrainement)
Y_model = model.predict(X_test_transformed)
print("test 6 :")
print("Mean absolute error (training data): ", mean_absolute_error(Y_test, Y_model))
print(f"Erreur quadratique moyenne (MSE) :",  mean_squared_error(Y_test, Y_model))

# Pas beaucoup plus concluent

# Test pour un décalage de 15 min du capteur 1 et de 30 min du capteur 2.

donnees,a, hours = read_data()

datashifted = donnees["x1"].shift(1)
donnees.iloc[:, 1] = datashifted
datashifted = donnees["x2"].shift(2)
donnees.iloc[:, 2] = datashifted

X_entrainement = donnees.iloc[2:3600, 0:3]
Y_entrainement = donnees.iloc[2:3600, 3]
X_test = donnees.iloc[3600:, 0:3]
Y_test = donnees.iloc[3600:, 3]

polynomial_features= PolynomialFeatures(degree=1, include_bias=False)
X_train_transformed = polynomial_features.fit_transform(X_entrainement)
X_test_transformed = polynomial_features.transform(X_test)

model = LinearRegression()
model.fit(X_train_transformed, Y_entrainement)
Y_model = model.predict(X_test_transformed)
print("test 7 :")
print("Mean absolute error (training data): ", mean_absolute_error(Y_test, Y_model))
print(f"Erreur quadratique moyenne (MSE) :",  mean_squared_error(Y_test, Y_model))

# Pas concluent 

# Test pour un décalage de 30 min du capteur 1 et de 15 min du capteur 2 : 

donnees,a, hours = read_data()

datashifted = donnees["x1"].shift(2)
donnees.iloc[:, 1] = datashifted
datashifted = donnees["x2"].shift(1)
donnees.iloc[:, 2] = datashifted

X_entrainement = donnees.iloc[2:3600, 0:3]
Y_entrainement = donnees.iloc[2:3600, 3]
X_test = donnees.iloc[3600:, 0:3]
Y_test = donnees.iloc[3600:, 3]

polynomial_features= PolynomialFeatures(degree=1, include_bias=False)
X_train_transformed = polynomial_features.fit_transform(X_entrainement)
X_test_transformed = polynomial_features.transform(X_test)

model = LinearRegression()
model.fit(X_train_transformed, Y_entrainement)
Y_model = model.predict(X_test_transformed)
print("test 8 :")
print("Mean absolute error (training data): ", mean_absolute_error(Y_test, Y_model))
print(f"Erreur quadratique moyenne (MSE) :",  mean_squared_error(Y_test, Y_model))
# Pas concluent


# Le meilleur test avec décalage est celui considérant un décalage de 30 min pour le capteur 1 et aucun pour le capteur 2.
# Out:
# test 1 :
# Mean absolute error (training data):  0.8511090385310817
# Erreur quadratique moyenne (MSE) : 1.0931517595719555
# test 2 :
# Mean absolute error (training data):  0.8377280495019552
# Erreur quadratique moyenne (MSE) : 1.0569555655171072
# test 3 :
# Mean absolute error (training data):  0.8925812299745257
# Erreur quadratique moyenne (MSE) : 1.2128921448758445
# test 4 :
# Mean absolute error (training data):  0.856872318877754
# Erreur quadratique moyenne (MSE) : 1.1126593410850525
# test 5 :
# Mean absolute error (training data):  0.9129320786510315
# Erreur quadratique moyenne (MSE) : 1.2707300614836738
# test 6 :
# Mean absolute error (training data):  0.8481059480288266
# Erreur quadratique moyenne (MSE) : 1.0831374878934927
# test 7 :
# Mean absolute error (training data):  0.8612305833838743
# Erreur quadratique moyenne (MSE) : 1.124198677458091
# test 8 :
# Mean absolute error (training data):  0.9007239993757798
# ...

# %%
# Voyons si les meilleurs cas testés ci-dessus améliorent l'erreur lorsque l'on considère 
# comme paramètres l'heure de la journée et le jour de la semaine

# Création d'un 1er modèle avec décalage temporel

# Création d'une table de données avec les caractéristiques importantes :
donnees, a, hours = read_data()

X1_shifted = donnees['x1'].shift(0)
X2_shifted = donnees['x2'].shift(2)
donnees_traitees = np.array([hour_of_day, day_of_week, X1_shifted, X2_shifted, donnees.iloc[:, 3]]).T

# Split des données entre données de test et données d'entrainement
X_entrainement = donnees_traitees[2:3600, 0:4]
Y_entrainement = donnees_traitees[2:3600, 4]
X_test = donnees_traitees[3600:, 0:4]
Y_test = donnees_traitees[3600:, 4]

# Créons un 1er modèle avec les données que nous avons noté :
polynomial_features= PolynomialFeatures(degree=5, include_bias=False)
X_train_transformed = polynomial_features.fit_transform(X_entrainement)
X_test_transformed = polynomial_features.transform(X_test)

model = LinearRegression()
model.fit(X_train_transformed, Y_entrainement)
Y_model = model.predict(X_test_transformed)
print("Mean absolute error (training data): ", mean_absolute_error(Y_test, Y_model))
print(f"Erreur quadratique moyenne (MSE) :",  mean_squared_error(Y_test, Y_model))

# En considérant un shift du capteur 2 de 30 min, nous avons un résultat encore plus proche du résultat optimal
# Out:
# Mean absolute error (training data):  0.4737269288035789
# Erreur quadratique moyenne (MSE) : 0.3366052429867674

# %%
#Model Alex
#D'apres la scikit learn cheat sheet map on doit utiliser la regression pour ce probleme
#Random forests peuvent modeliser des relations complexes non lineaires, dans notre cas y depend du temps mais aussi l'interaction entre x1 and x2 n'est pas lineaire
#Elle capture automatiquement les interactions sans devoir les decrire explicitement

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.model_selection import train_test_split

data = pd.read_csv('projet_2_data.csv')
data_hold = pd.read_csv('projet_2_hold_out.csv')

data['timestamp'] = pd.to_datetime(data['timestamp'])

data['hour'] = data['timestamp'].dt.hour
data['weekday'] = data['timestamp'].dt.weekday

data['x1_lag1'] = data['x1'].shift(1)
data['x2_lag1'] = data['x2'].shift(1)
data['x1_lag2'] = data['x1'].shift(2)
data['x2_lag2'] = data['x2'].shift(2)

data = data.dropna()

predictors = ['x1', 'x2', 'x1_lag1', 'x2_lag1', 'x1_lag2', 'x2_lag2', 'hour', 'weekday']
X = data[predictors]
y = data['y']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

model_alex = RandomForestRegressor(random_state=42, n_estimators=100)
model_alex.fit(X_train, y_train)

y_pred = model_alex.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test,y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
print(f"Mean Absolute Error: {mae}")


#GPT me montre comment avoir l'accuracy
# Bin the true and predicted values into categories
binner = KBinsDiscretizer(n_bins=3, encode='ordinal', strategy='uniform')  # Adjust n_bins as needed
y_test_binned = binner.fit_transform(y_test.values.reshape(-1, 1)).astype(int).ravel()
y_pred_binned = binner.transform(y_pred.reshape(-1, 1)).astype(int).ravel()

# Calculate accuracy
accuracy = accuracy_score(y_test_binned, y_pred_binned)
print(f"Accuracy: {accuracy}")

#scatter plot pour visualiser les valeurs predite vs vraiess
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.6, edgecolor='k')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--', linewidth=2)
plt.title('Actual vs Predicted Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.grid(True)
plt.show()
# Out:
# Mean Squared Error: 0.08834619739494427
# R² Score: 0.9306873636521042
# Mean Absolute Error: 0.23822670167346022
# Accuracy: 0.8828125

# %%
data_hold['timestamp'] = pd.to_datetime(data_hold['timestamp'])

data_hold['hour'] = data_hold['timestamp'].dt.hour
data_hold['weekday'] = data_hold['timestamp'].dt.weekday

data_hold['x1_lag1'] = data_hold['x1'].shift(1)
data_hold['x2_lag1'] = data_hold['x2'].shift(1)
data_hold['x1_lag2'] = data_hold['x1'].shift(2)
data_hold['x2_lag2'] = data_hold['x2'].shift(2)

data_hold = data_hold.dropna()

predictors = ['x1', 'x2', 'x1_lag1', 'x2_lag1', 'x1_lag2', 'x2_lag2', 'hour', 'weekday']
X_2 = data_hold[predictors]
y_pred2 = model_alex.predict(X_2)

print(len(y_pred2))

tracer_fonction(X_2['weekday'], y_pred2, 'c', 'd')
# Out:
# 956

# %% [markdown]
# Veuillez adapter la fonction ci-dessous pour qu'elle génère une _DataFrame_ pandas utilisable pour l'entraînement ou l'évaluation de votre modèle prédictif à partir d'un fichier CSV de données brutes.
#
# Cette fonction doit prendre en paramètre le fichier CSV contenant les données historiques, avec ou sans la variable cible *y*, par example _projet_2_data.csv_ ou _projet_2_hold_out.csv_.
#
# Elle doit retourner un tuple Python contenant les éléments suivants, dans cet ordre :
#
# 1. Une _pandas.DataFrame_ des caractéristiques (_X_) utilisées comme entrées pour le modèle de prédiction.
# 2. Une _pandas.Series_ contenant les valeurs connues de la variable cible (_y_), si celle-ci est présente dans les données. Sinon, la fonction doit retourner _None_ à la place.
# 3. Une _pandas.Series_ des timestamps correspondant aux instants de prédiction de _y_.
#
# Assurez-vous que _X_, _y_ (si présent), et les timestamps ont **la même taille** afin de garantir la cohérence des données.

# %%
def inputTransform(fichier=hold_out_filename):
    df = pd.read_csv(fichier, parse_dates=['timestamp'])

    # Ajouter des caractéristiques temporelles
    df['hour'] = df['timestamp'].dt.hour
    df['weekday'] = df['timestamp'].dt.weekday

    # Encodage cyclique pour l'heure
    df['sin_hour'] = np.sin(2 * np.pi * df['hour'] / 24)
    df['cos_hour'] = np.cos(2 * np.pi * df['hour'] / 24)

    df['x1_lag1'] = df['x1'].shift(1)
    df['x2_lag1'] = df['x2'].shift(1)
    df['x1_lag2'] = df['x1'].shift(2)
    df['x2_lag2'] = df['x2'].shift(2)

    # Supprimer les lignes avec des valeurs manquantes
    df = df.dropna()

    features_used_by_model = ['x1', 'x2', 'x1_lag1', 'x2_lag1', 'x1_lag2', 'x2_lag2', 'sin_hour', 'cos_hour']
    if 'y' in df.columns:
        df = df[features_used_by_model + ['timestamp', 'y']]
    else:
        df = df[features_used_by_model + ['timestamp']]

    X = df.loc[:, ~df.columns.isin(['timestamp'])]
    if hasattr(df, 'y'):
        y = df.y
        return (X, y, df.timestamp)
    else:
        return (X, None, df.timestamp)

# %% [markdown]
# ---
# #### Verification
#
# Veuillez valider votre modèles à l'aide de la fonction ci-dessous, vous devez entrer votre modèle de prédiction, ainsi que la fonction de transformation de la donnée de test (inputGenerator=...).
#
# ⚠️ - Cette fonction vérifie uniquement que votre soumission est vérifiable. Elle ne donne aucune indication sur la validité de la soumission (e.g. type de ML) ou sa qualité.

# %%
# executer la commande ci-dessous si nécessaire (enlever le #).
# !pip install -e ./eng209

# %%
from importlib import reload
import eng209.verify
reload(eng209.verify)
from eng209.verify import verify_q2

# %%
# Remplacez model par votre modèle
model = model_alex
verify_q2(model_alex, inputGenerator=inputTransform)
# Out:
# Vérification ...
# Vérifiable
